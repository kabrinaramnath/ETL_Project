# %%
import pandas as pd
import os

# %%
file_one = os.path.join("permits_cust.csv")

# %%
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
file_one_df
# Out:
#     Year     Total  Northeast  Midwest     South   West
# 0   1959  1,208.00      222.0    286.0       356  344.0
# 1   1960     997.6      199.1    228.0     284.1  286.3
# 2   1961  1,064.20      229.4    226.1     299.4  309.4
# 3   1962  1,186.60      242.5    238.3     342.8  363.0
# 4   1963  1,334.70      239.4    268.8     403.2  423.3
# 5   1964  1,285.80      243.4    286.9     401.4  354.2
# 6   1965  1,240.60      252.7    310.5     408.3  269.1
# 7   1966     971.9      209.8    250.9     331.1  180.2
# 8   1967  1,141.00      222.6    309.8     390.8  217.8
# 9   1968  1,353.40      234.8    350.1     477.3  291.1
# 10  1969  1,322.30      215.8    317.0     470.5  319.0
# 11  1970  1,351.50      218.3    287.4     502.9  342.9
# 12  1971  1,924.60      303.6    421.1     725.4  474.6
# 13  1972  2,218.90      333.3    440.8     905.4  539.3
# 14  1973  1,819.50      271.9    361.4     763.2  423.1
# 15  1974  1,074.40      165.4    241.3     390.1  277.6
# ...

# %%
file_one_df.to_csv("Output/USHousingPermitsbyRegion.csv", index=False, header=True)
