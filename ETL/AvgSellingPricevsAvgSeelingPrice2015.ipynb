# %%
import pandas as pd
import os

# %%
file_one = os.path.join("price_sold_cust.csv")

# %%
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")

# %%
file_one_df
# Out:
#     Year Price (AVG of Houses Sold) Percent Change  \
# 0   1963                   $ 19,300            (X)
# 1   1964                   $ 20,500           6.2%
# 2   1965                   $ 21,500           4.9%
# 3   1966                   $ 23,300           8.4%
# 4   1967                   $ 24,600           5.6%
# 5   1968                   $ 26,600           8.1%
# 6   1969                   $ 27,900           4.9%
# 7   1970                   $ 26,600          -4.7%
# 8   1971                   $ 28,300           6.4%
# 9   1972                   $ 30,500           7.8%
# 10  1973                   $ 35,500          16.4%
# 11  1974                   $ 38,900           9.6%
# 12  1975                   $ 42,600           9.5%
# 13  1976                   $ 48,000          12.7%
# 14  1977                   $ 54,200          12.9%
# 15  1978                   $ 62,500          15.3%
# 16  1979                   $ 71,800          14.9%
# ...

# %%
file_one_df.to_csv("Output/AvgSellingPricesvsAvgSellingPrice2015.csv", index=False, header=True)
